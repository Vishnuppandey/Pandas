# %%
import pandas as pd

# %%
p1=["Vishnu","Kant","Pandey"]

# %%
pd.Series(p1)
# Out:
# 0    Vishnu
# 1      Kant
# 2    Pandey
# dtype: object

# %%
ind=[1,2,3,4]

# %%
p2=[100,99,98,97]
pd.Series(p2,ind)
# Out:
# 1    100
# 2     99
# 3     98
# 4     97
# dtype: int64

# %%
marks=[100,98,99,97]

# %%
subjects=["Math","Science","English","Hindi"]

# %%
pd.Series(marks,index=subjects,name="Marks of Vishnu")
# Out:
# Math       100
# Science     98
# English     99
# Hindi       97
# Name: Marks of Vishnu, dtype: int64

# %%
dicti={
    'Maths':100,
    'Science':98,
    'English':99,
    'Hindi':97
}

# %%
marks_series=pd.Series(dicti,name="Marks of Vishnu")

# %%
pd.Series([1,2,3,4,5]).is_unique
# Out:
# True

# %%
marks_series.index
# Out:
# Index(['Maths', 'Science', 'English', 'Hindi'], dtype='object')

# %%
type(marks_series.index)
# Out:
# pandas.core.indexes.base.Index

# %%
marks_series.values
# Out:
# array([100,  98,  99,  97], dtype=int64)

# %% [markdown]
# type(marks_series.values)

# %%
type(marks_series.values)
# Out:
# numpy.ndarray

# %%
data=pd.read_csv("D:/Pandas/student.csv")
data
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
data.tail()
# Out:
#     id         name  class  mark  gender
# 30  31  Marry Toeey   Four    88    male
# 31  32    Binn Rott  Seven    90  female
# 32  33    Kenn Rein    Six    96  female
# 33  34     Gain Toe  Seven    69    male
# 34  35   Rows Noump    Six    88  female

# %%
data.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
dataf=pd.read_excel("D:/Pandas/student.xlsx")
dataf
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob   Five    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
dataf.tail(10)
# Out:
#     id         name  class  mark  gender
# 25  26       Crelea  Seven    79    male
# 26  27     Big Nose  Three    81  female
# 27  28    Rojj Base  Seven    86  female
# 28  29  Tess Played  Seven    55    male
# 29  30    Reppy Red    Six    79  female
# 30  31  Marry Toeey   Four    88    male
# 31  32    Binn Rott  Seven    90  female
# 32  33    Kenn Rein    Six    96  female
# 33  34     Gain Toe  Seven    69    male
# 34  35   Rows Noump    Six    88  female

# %%
dataf.head(10)
# Out:
#    id         name  class  mark  gender
# 0   1     John Deo   Four    75  female
# 1   2     Max Ruin  Three    85    male
# 2   3       Arnold  Three    55    male
# 3   4   Krish Star   Four    60  female
# 4   5    John Mike   Four    60  female
# 5   6    Alex John   Four    55    male
# 6   7  My John Rob   Five    78    male
# 7   8       Asruid   Five    85    male
# 8   9      Tes Qry    Six    78    male
# 9  10     Big John   Four    55  female

# %%
datafr=pd.read_csv("D:/Pandas/student.csv")
datafr
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
datafr.sample()
# Out:
#     id    name class  mark  gender
# 19  20  Jackly  Nine    65  female

# %%
datafr.sample(10)
# Out:
#     id         name  class  mark  gender
# 25  26       Crelea  Seven    79    male
# 5    6    Alex John   Four    55    male
# 10  11       Ronald    Six    89  female
# 6    7  My John Rob  Fifth    78    male
# 24  25     Giff Tow  Seven    88    male
# 14  15     Tade Row   Four    88    male
# 11  12        Recky    Six    94  female
# 26  27     Big Nose  Three    81  female
# 16  17        Tumyu    Six    54    male
# 31  32    Binn Rott  Seven    90  female

# %%
datafr.sort_values(by='mark',ascending=True)
# Out:
#     id         name  class  mark  gender
# 18  19        Tinny   Nine    18    male
# 16  17        Tumyu    Six    54    male
# 28  29  Tess Played  Seven    55    male
# 2    3       Arnold  Three    55    male
# 5    6    Alex John   Four    55    male
# 21  22       Reggid  Seven    55  female
# 9   10     Big John   Four    55  female
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 33  34     Gain Toe  Seven    69    male
# 0    1     John Deo   Four    75  female
# 17  18        Honny   Five    75    male
# 8    9      Tes Qry    Six    78    male
# 6    7  My John Rob  Fifth    78    male
# 23  24    Tiddy Now  Seven    78    male
# 29  30    Reppy Red    Six    79  female
# 22  23        Herod  Eight    79    male
# 25  26       Crelea  Seven    79    male
# 26  27     Big Nose  Three    81  female
# 1    2     Max Ruin  Three    85    male
# ...

# %%
datafr.sort_values(by='mark',ascending=False)
# Out:
#     id         name  class  mark  gender
# 32  33    Kenn Rein    Six    96  female
# 11  12        Recky    Six    94  female
# 31  32    Binn Rott  Seven    90  female
# 10  11       Ronald    Six    89  female
# 24  25     Giff Tow  Seven    88    male
# 15  16        Gimmy   Four    88    male
# 14  15     Tade Row   Four    88    male
# 13  14         Bigy  Seven    88  female
# 12  13          Kty  Seven    88  female
# 34  35   Rows Noump    Six    88  female
# 30  31  Marry Toeey   Four    88    male
# 27  28    Rojj Base  Seven    86  female
# 7    8       Asruid   Five    85    male
# 1    2     Max Ruin  Three    85    male
# 26  27     Big Nose  Three    81  female
# 22  23        Herod  Eight    79    male
# 29  30    Reppy Red    Six    79  female
# 25  26       Crelea  Seven    79    male
# 8    9      Tes Qry    Six    78    male
# 6    7  My John Rob  Fifth    78    male
# 23  24    Tiddy Now  Seven    78    male
# 0    1     John Deo   Four    75  female
# ...

# %%
datafr.sort_index()
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
datafr.count()
# Out:
# id        35
# name      35
# class     35
# mark      35
# gender    35
# dtype: int64

# %%
datas=pd.read_csv("D:/Pandas/flights_cleaned.csv")
datas
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 0            Jet Airways      2019-01-03  Banglore   New Delhi
# 1               SpiceJet      2019-01-03  Banglore   New Delhi
# 2            Jet Airways      2019-01-03  Banglore   New Delhi
# 3              Air India      2019-01-03  Banglore   New Delhi
# 4            Jet Airways      2019-01-03  Banglore   New Delhi
# ...                  ...             ...       ...         ...
# 10678  Multiple carriers      2019-12-06     Delhi      Cochin
# 10679             IndiGo      2019-12-06   Kolkata    Banglore
# 10680        Jet Airways      2019-12-06     Delhi      Cochin
# 10681           Air Asia      2019-12-06   Kolkata    Banglore
# 10682        Jet Airways      2019-12-06     Delhi      Cochin
#
#                        Route Dep_Time  Duration Total_Stops  Price
# 0            BLR → BOM → DEL    11:40       785      1 stop  26890
# 1            BLR → HYD → DEL    15:35       485      1 stop   7744
# ...

# %%
x=pd.Series([1,2,3,4,5,6,7,8,9])

# %%
x[0]
# Out:
# 1

# %%
x[8]
# Out:
# 9

# %%
marks=
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [43], in <module>
# ----> 1 datas[Airline]
#
# NameError: name 'Airline' is not defined

# %%
marks_series["SST"]=100

# %%
marks_series
# Out:
# Maths      100
# Science     98
# English     99
# Hindi       97
# SST        100
# Name: Marks of Vishnu, dtype: int64

# %%
marks_series["sc"]=90

# %%
marks_series
# Out:
# Maths      100
# Science     98
# English     99
# Hindi       97
# SST        100
# sc          90
# Name: Marks of Vishnu, dtype: int64

# %%
list(marks_series)
# Out:
# [100, 98, 99, 97, 100, 90]

# %%
dict(marks_series)
# Out:
# {'Maths': 100, 'Science': 98, 'English': 99, 'Hindi': 97, 'SST': 100, 'sc': 90}

# %%
10 in marks_series.values
# Out:
# False

# %%
99 in marks_series.values
# Out:
# True

# %%
100-marks_series
# Out:
# Maths       0
# Science     2
# English     1
# Hindi       3
# SST         0
# sc         10
# Name: Marks of Vishnu, dtype: int64

# %%
100+marks_series
# Out:
# Maths      200
# Science    198
# English    199
# Hindi      197
# SST        200
# sc         190
# Name: Marks of Vishnu, dtype: int64

# %%
datas.plot()
# Out:
# <Axes: >

# %%
datas.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
